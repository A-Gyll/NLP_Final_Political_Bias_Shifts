# %%
from encode import ExploratoryAnalysis

# %%
file_class_map = {
    'Fox_News_comments_clean.csv': 'right',
    'CNN_comments_clean.csv': 'left'
}

folder_path = '/Users/smutnuri/Documents/UVA/_Projects/Fall24/NLP/NLPRepo/data/Cleaned Data'
n_samples = 2000

# %%
random_analysis = ExploratoryAnalysis(folder_path, 
                                      file_to_class_mapping=file_class_map, 
                                      is_random=True, 
                                      n_samples=n_samples)
random_analysis.run(method='tsne')
random_analysis.run(method='umap')
# Out:
# ...
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# /Users/smutnuri/opt/anaconda3/envs/nlpenv/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
analysis = ExploratoryAnalysis(folder_path, 
                                      file_to_class_mapping=file_class_map, 
                                      is_random=False, 
                                      n_samples=n_samples)
analysis.run(method='tsne')
analysis.run(method='umap')
# Out:
# ...
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# /Users/smutnuri/opt/anaconda3/envs/nlpenv/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
